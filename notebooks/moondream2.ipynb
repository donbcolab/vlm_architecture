# %% [markdown]
# <a href="https://colab.research.google.com/github/donbcolab/vlm_architecture/blob/main/notebooks/moondream2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Moondream
#
# - see [model card](https://huggingface.co/vikhyatk/moondream2) for more details

# %% [markdown]
# ## Install Python Dependencies

# %%
# !pip install transformers einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import necessary libraries

# %%
from PIL import Image
import requests
from transformers import AutoModelForCausalLM
from transformers import AutoTokenizer
import torch

# %% [markdown]
# ## Hugging Face model configuration
# - Load the vision model and processor from Hugging Face

# %%
# Hugging Face model configuration

model_id = "vikhyatk/moondream2"
revision = "2024-05-20"

device = "cuda" if torch.cuda.is_available() else "cpu"

model = AutoModelForCausalLM.from_pretrained(
    model_id, trust_remote_code=True, revision=revision
)
tokenizer = AutoTokenizer.from_pretrained(model_id, revision=revision)
# Out:
# config.json:   0%|          | 0.00/319 [00:00<?, ?B/s]
# configuration_moondream.py:   0%|          | 0.00/3.41k [00:00<?, ?B/s]
# moondream.py:   0%|          | 0.00/5.29k [00:00<?, ?B/s]
# vision_encoder.py:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# modeling_phi.py:   0%|          | 0.00/48.0k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.73G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ## Visualize the Model Architecture
#
# - Print the model architecture to understand its structure

# %%
# Visualize the Model Architecture

print(model)
# Out:
# Moondream(
#   (vision_encoder): VisionEncoder(
#     (encoder): EncoderWrapper(
#       (model): ModuleDict(
#         (visual): VisionTransformer(
#           (patch_embed): LinearPatchEmbedding(
#             (linear): Linear(in_features=588, out_features=1152, bias=True)
#           )
#           (blocks): Sequential(
#             (0): VitBlock(
#               (attn): Attention(
#                 (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#                 (proj): Linear(in_features=1152, out_features=1152, bias=True)
#               )
#               (mlp): MLP(
#                 (fc1): Linear(in_features=1152, out_features=4304, bias=True)
#                 (act): GELU(approximate='tanh')
#                 (fc2): Linear(in_features=4304, out_features=1152, bias=True)
#               )
#               (norm1): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#               (norm2): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
# ...

# %% [markdown]
# ## Setup the input for the Vision model

# %% [markdown]
# ## Setup and Run Vision model inference

# %% [markdown]
# ## Discover the Model's Insights!
